# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
binning_df = pd.read_csv('coverage.csv')

# %%
binning_df.columns = ['index','count']

# %%
plt.figure(figsize=(10,4))
plt.plot(binning_df['index'],binning_df['count'])
plt.show()
